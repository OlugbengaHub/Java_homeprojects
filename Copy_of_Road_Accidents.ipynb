# %% [markdown]
# <a href="https://colab.research.google.com/github/OlugbengaHub/Java_homeprojects/blob/master/Copy_of_Road_Accidents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import important libraries**

# %%
import pandas as pd

df=pd.read_csv("/content/Road-Accidents.csv")

# %% [markdown]
# **Read the dataset**

# %%
df.head()
# Out:
#    Accident_Index Accident_Severity Accident_Date Weekday Accident_Time  \
# 0               1            Slight     01-Jan-25  Monday      01:30:00
# 1               2            Slight     01-Jan-25  Monday      00:50:00
# 2               3            Slight     01-Jan-25  Monday      00:45:00
# 3               4           Serious     01-Jan-25  Monday      03:00:00
# 4               5           Serious     01-Jan-25  Monday      02:20:00
#
#             Road_Type  Speed_limit               Lighting  \
# 0    Dual carriageway           30  Darkness - lights lit
# 1  Single carriageway           30  Darkness - lights lit
# 2  Single carriageway           20  Darkness - lights lit
# 3    Dual carriageway           30  Darkness - lights lit
# 4  Single carriageway           30  Darkness - lights lit
#
#                  Weather Surface conditions Urban_or_Rural_Area
# 0     Fine no high winds                Dry               Urban
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122634 entries, 0 to 122633
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Accident_Index       122634 non-null  int64
#  1   Accident_Severity    122634 non-null  object
#  2   Accident_Date        122634 non-null  object
#  3   Weekday              122634 non-null  object
#  4   Accident_Time        122621 non-null  object
#  5   Road_Type            122634 non-null  object
#  6   Speed_limit          122634 non-null  int64
#  7   Lighting             122634 non-null  object
#  8   Weather              122615 non-null  object
#  9   Surface conditions   121411 non-null  object
#  10  Urban_or_Rural_Area  122579 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 10.3+ MB

# %%
df.isnull().sum()
# Out:
# Accident_Index            0
# Accident_Severity         0
# Accident_Date             0
# Weekday                   0
# Accident_Time            13
# Road_Type                 0
# Speed_limit               0
# Lighting                  0
# Weather                  19
# Surface conditions     1223
# Urban_or_Rural_Area      55
# dtype: int64

# %%
df['Weather'].unique()
# Out:
# array(['Fine no high winds', 'Raining no high winds',
#        'Raining + high winds', 'Unknown', 'Fine + high winds', 'Other',
#        'Snowing + high winds', 'Snowing no high winds', 'Fog or mist',
#        nan], dtype=object)

# %%
df['Weather'].value_counts()
# Out:
# Weather
# Fine no high winds       99221
# Raining no high winds    12788
# Unknown                   3666
# Other                     2603
# Raining + high winds      1277
# Fine + high winds         1134
# Snowing no high winds     1075
# Fog or mist                449
# Snowing + high winds       402
# Name: count, dtype: int64

# %% [markdown]
# **Replace Unknown values with 'Other'**

# %%
df['Weather'].replace("Unknown", "Other", inplace = True)
# Out:
# <ipython-input-18-ba038006ebcc>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Weather'].replace("Unknown", "Other", inplace = True)

# %%
new_df = df.replace('Unknown', 'Other')
new_df.head()
# Out:
#    Accident_Index Accident_Severity Accident_Date Weekday Accident_Time  \
# 0               1            Slight     01-Jan-25  Monday      01:30:00
# 1               2            Slight     01-Jan-25  Monday      00:50:00
# 2               3            Slight     01-Jan-25  Monday      00:45:00
# 3               4           Serious     01-Jan-25  Monday      03:00:00
# 4               5           Serious     01-Jan-25  Monday      02:20:00
#
#             Road_Type  Speed_limit               Lighting  \
# 0    Dual carriageway           30  Darkness - lights lit
# 1  Single carriageway           30  Darkness - lights lit
# 2  Single carriageway           20  Darkness - lights lit
# 3    Dual carriageway           30  Darkness - lights lit
# 4  Single carriageway           30  Darkness - lights lit
#
#                  Weather Surface conditions Urban_or_Rural_Area
# 0     Fine no high winds                Dry               Urban
# ...

# %%
df['Weather'].value_counts()
# Out:
# Weather
# Fine no high winds       101268
# Raining no high winds     13113
# Other                      3768
# Raining + high winds       1306
# Fine + high winds          1164
# Snowing no high winds      1112
# Fog or mist                 465
# Snowing + high winds        418
# Name: count, dtype: int64

# %% [markdown]
# **Drop all the null values**

# %%
new_df.dropna(inplace=True)

# %%
new_df.isnull().sum()
# Out:
# Accident_Index         0
# Accident_Severity      0
# Accident_Date          0
# Weekday                0
# Accident_Time          0
# Road_Type              0
# Speed_limit            0
# Lighting               0
# Weather                0
# Surface conditions     0
# Urban_or_Rural_Area    0
# dtype: int64
